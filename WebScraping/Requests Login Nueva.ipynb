# %%
import requests
import lxml.html
from bs4 import BeautifulSoup

# %%
url = 'https://my.nuevaschool.org/signin.php'
username = 'cshan'
password = open('./password.txt').read().strip()

# %%
login_url = url

# %%
s = requests.Session()
login = s.get(login_url)
login_html = lxml.html.fromstring(login.text)
hidden_inputs = login_html.xpath(r'//form//input[@type="hidden"]')
form = {x.attrib["name"]: x.attrib["value"] for x in hidden_inputs}

# %%
form
# Out:
# {'signin': 'Sign In'}

# %%
form['signin_acct'] = username
form['signin_pw'] = password

# %%
form
# Out:
# {'signin': 'Sign In', 'signin_acct': 'cshan', 'signin_pw': '4Brothers'}

# %%
response = s.post(login_url, data=form)

# %%
response.url
# Out:
# 'https://my.nuevaschool.org/base.php?q__=QJhpqkdVGEREshYXD4uR8A%3D%3D'

# %%
response.ok
# Out:
# True

# %%
soup = BeautifulSoup(response.text, 'html5lib')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html><head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <!-- <link type="text/css" href="/lib/js/css/ui-lightness/jquery-ui-1.8.6.custom.css" rel="Stylesheet"/> -->
# <!-- <script type="text/javascript" src="/lib/js/jquery-1.5.1.min.js"></script> -->
# <!-- <script type="text/javascript" src="/lib/js/jquery-ui-1.8.12.custom.min.js"></script> -->
#
# <!-- JQuery Latest Version 07/16/2014 -->
# <link href="/resources/jquery-ui-1.11.0/jquery-ui.min.css" rel="Stylesheet" type="text/css"/>
# <script src="/resources/js/jquery-1.11.1.min.js" type="text/javascript"></script>
# <script src="/resources/jquery-ui-1.11.0/jquery-ui.min.js" type="text/javascript"></script>
# <!-- Dropzone -->
# <script src="/resources/js/dropzone.js" type="text/javascript"></script>
# <link href="/resources/js/dropzone.css" rel="Stylesheet" type="text/css"/>
# <!-- Twitter BootStrap CSS framework -->
# <link href="/resources/bootstrap-3.2.0-dist/css/bootstrap.min.css" media="all" rel="Stylesheet" type="text/css"/>
# <link href="/resources/bootstrap-3.2.0-dist/css/bootstrap-theme.min.css" media="all" rel="Stylesheet" type="text/css"/>
# <link href="/resources/font-awesome-4.4.0/css/font-awesome.min.css" rel="stylesheet"/>
# <script src="/resources/bootstrap-3.2.0-dist/js/bootstrap.min.js" type="text/javascript"></script>
# <!--  tinyMCE Editor -->
# <script src="/resources/tinymce-4.1.5/js/tinymce/tinymce.min.js" type="text/javascript"></script>
# <!-- JQuery Validator -->
# <script src="/resources/jquery-validation-1.14.0/dist/jquery.validate.min.js" type="text/javascript"></script>
# <!-- Nueva custom css -->
# <link href="/resources/css/nueva.css" rel="Stylesheet" type="text/css"/>
# <!-- <script type="text/javascript" src="/resources/js/nueva.main.js"></script> -->
#
# <script type="text/javascript">
# var tm_fonts = "Andale Mono=andale mono,times;"+
# "Arial=arial,helvetica,sans-serif;"+
# "Arial Black=arial black,avant garde;"+
# "Book Antiqua=book_antiquaregular,palatino;"+
# "Century Gothic=Century Gothic,Arial, sans-serif;" +
# "Corda Light=CordaLight,sans-serif;"+
# "Courier New=courier_newregular,courier, mono;"+
# "Flexo Caps=FlexoCapsDEMORegular;"+
# "Lucida Console=lucida_consoleregular,courier;"+
# "Georgia=georgia,palatino;"+
# "Helvetica=helvetica;"+
# "Impact=impactregular,chicago;"+
# "Museo Slab=MuseoSlab500Regular,sans-serif;"+
# "Museo Sans=MuseoSans500Regular,sans-serif;"+
# "Oblik Bold=OblikBoldRegular;"+
# "Sofia Pro Light=SofiaProLightRegular;"+
# "Symbol=webfontregular;"+
# "Tahoma=tahoma,arial,helvetica,sans-serif;"+
# "Terminal=terminal,monaco;"+
# "Tikal Sans Medium=TikalSansMediumMedium;"+
# "Times New Roman=times new roman,times;"+
# "Trebuchet MS=trebuchet ms,geneva;"+
# "Verdana=Verdana, Arial, Helvetica, sans-serif;"+
# "Webdings=webdings;"+
# "Wingdings=wingdings,zapf dingbats"+
# "Aclonica=Aclonica, sans-serif;"+
# "Michroma=Michroma;"+
# "Paytone One=Paytone One, sans-serif;"+
# "Andalus=andalusregular, sans-serif;"+
# "Arabic Style=b_arabic_styleregular, sans-serif;"+
# "Andalus=andalusregular, sans-serif;"+
# "KACST_1=kacstoneregular, sans-serif;"+
# "Mothanna=mothannaregular, sans-serif;"+
# "Nastaliq=irannastaliqregular, sans-serif;"+
# "Samman=sammanregular";
#
# var cip='207.47.5.18';var ss='5faf4ea53edf11b4eb1d54389cf0951b';    // single day on page
#     $(function () {
#         $("#datepicker").datepicker();
#     });
#     // from to
#     $(function () {
#         var dates = $("#from, #to").datepicker({
#             defaultDate:"+1w",
#             changeMonth:true,
#             numberOfMonths:1,
#
#             onSelect:function (selectedDate) {
#                 var option = this.id == "from" ? "minDate" : "maxDate",
#                     instance = $(this).data("datepicker"),
#                     date = $.datepicker.parseDate(
#                         instance.settings.dateFormat ||
#                             $.datepicker._defaults.dateFormat,
#                         selectedDate, instance.settings);
#                 dates.not(this).datepicker("option", option, date);
#             }
#         });
#     });
#
#     /*
#     // modal dialog for id="modal" div's
#     $(function() {
#         $( "#dialog").dialog();
#     });
#     */
#
#     // use class and id to get multiple instances:
#     /*
#     from:  http://stackoverflow.com/questions/707603/apply-jquery-datepicker-to-multiple-instances
#     <!-- Each input field needs a unique id, but all need to be datepicker -->
#     <p>Date 1: <input id="one" class="datepicker" type="text" readonly="true"></p>
#    <p>Date 2: <input id="two" class="datepicker" type="text" readonly="true"></p>
#     <p>Date 3: <input id="three" class="datepicker" type="text" readonly="true"></p>
#     */
#
#     $(function () {
#         $('input').filter('.datepicker').datepicker({});
#     });
#
#     //change password
#     var cw=null;
#     var save=null;
#     $.validator.addMethod("passwordRegex", function(value, element) {
#         return this.optional(element) || /^\S+$/i.test(value);
#     }, "No white space allowed");
#
#
#     $.validator.setDefaults({
#         submitHandler: function() {
#             //alert("submitted!");
#             $.post("/orgs/nueva/service/rest/changepw.php", $("#change_password_form").serialize())
#                 .done(function (data) {
#                     //alert("second success");
#                     if(!data.success)
#                         $("#change_password_status").css("color", "red").text("ERROR: " + data.message);
#                     else {
#                         $("#change_password_status").css("color", "red").text(data.message);
#                         setTimeout(function(){cw.modal('hide');}, 1000);
#                     }
#                 })
#                 .fail(function (data) {
#                     //alert("error");
#                     $("#change_password_status").css("color", "red").text(data.message);
#                 })
#                 .always(function () {});
#
#         }
#     });
#
#     $(function(){
#         cw=$('#change_password');
#
#         $("#change_password_form").validate({
#             rules: {
#                 current_password: {
#                     required: true,
#                     minlength: 7
#                 },
#                 new_password: {
#                     required: true,
#                     minlength: 7,
#                     passwordRegex: true
#                 },
#                 confirm_new_password: {
#                     required: true,
#                     minlength: 7,
#                     equalTo: "#new_password"
#                 }
#
#             },
#             messages: {
#                 current_password: {
#                     required: "Please provide your current password",
#                     minlength: "Your password must be at least 7 characters long"
#                 },
#                 password: {
#                     required: "Please provide a password",
#                     minlength: "Your password must be at least 7 characters long"
#                 },
#                 confirm_password: {
#                     required: "Please provide a password",
#                     minlength: "Your password must be at least 7 characters long",
#                     equalTo: "Please enter the same password as above"
#                 }
#             }
#         });
#
#
#
#     });
#
#     function loadChangeModal(){
#         if(cw!=null) {
#                 cw.modal({backdrop: 'static', keyboard: false});
#                 cw.modal('show');
#         }
#
# //        var edValue = document.getElementById("edValue");
# //        if(edValue!=null) {
# //            edValue.focus();
# //            edValue.value("card code");
# //        }
#     }
#     //end of change password
#
#
#     // time picker  not used yet
#     /*
#     $(function () {
#         $("#time0").timepicker({
#             stepMinute:5,
#             ampm:true,
#             hourMin:7,
#             hourMax:22
#         });
#     });
#     */
#
#     // wait cursor and clear cursor
#     function cursor_wait() {
#         document.body.style.cursor = 'wait';
#     }
#
#     function cursor_clear() {
#         document.body.style.cursor = 'default';
#     }
#
#     // yes/no confirmation popup
#     function confirmation(prompt, yesURL) {
#         var answer = confirm(prompt + "?")
#         if (answer) {
#             window.location = yesURL;
#         }
#         else {
#             var nothing = 1;
#         }
#     }
#
#     // Inject a snippet of css that contains <style>...</style> into head element of page
#     function injectCSSstyle(snippet) {
#         var headTag = document.getElementsByTagName("head")[0].innerHTML;
#         var newCSS = headTag + snippet;
#         document.getElementsByTagName('head')[0].innerHTML = newCSS;
#     }
#
# </script>
#
#
# <title>The Nueva School Home</title>
#
#
# <link href="orgs/nueva/css.php" media="screen" rel="stylesheet" type="text/css"/></head><body onload="loadChangeModal();"><div class="navbar navbar-default" role="navigation"> <!--  navbar-fixed-top -->
# <div class="container">
# <div class="navbar-header">
# <button class="navbar-toggle collapsed" data-target=".navbar-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span><b>Menu</b></span>
# 		<!--
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# 		-->
# </button>
# <a class="navbar-brand" href="http://www.nuevaschool.org">
# <img alt="The Nueva School" height="42" src="/orgs/nueva/images/short_logo.png" style="border: none;margin-top:5px;margin-right:5px;" width="80"/>
# </a>
# <!-- a href="#" class="navbar-brand">Project name</a -->
# </div>
# <div class="navbar-collapse collapse">
JL38Gg%2Bm35RNaKu5BgPQYIOuQ">ATHLETICS</a></li><li><a href="https://my.nuevaschool.org/base.php?q__=nxBka6ECLwbOcAqUOXWqjqekRDGK2V2aDBwZR2gb3Db0MfffiITVylCptSCjUKEferWCvzPuPR8lYbvzf3QHLQ%3D%3D">HOMEWORK</a></li><li><a href="https://my.nuevaschool.org/base.php?q__=nxBka6ECLwbOcAqUOXWqjhr8LCbVf4RXd1ZR0xWLTeNKaWiCfWl4WOOZ1j31PvE7">ALUMNI</a></li><li><a href="https://my.nuevaschool.org/base.php?q__=nxBka6ECLwbOcAqUOXWqjnxix9BcGHFfH0qUpexhglD3HE%2FXgiiWHzbu4kdWYu42">SOCIAL JUSTICE</a></li><li><a href="https://my.nuevaschool.org/base.php?q__=L%2FZxTQ6x2GqrymgYvkFPSQUMdiaYb6kMOoFOxDjaaS0%3D">FACILITIES</a></li><li><a href="https://my.nuevaschool.org/base.php?q__=HS0MQwX4DjXlHDWhM63NJ%2BeJP58I0y8qR86aqe3R7%2B9t7PiKaUAFrvMN8NaDR3J9">ADD RESERVATION</a></li></ul></li><li class="dropdown"><a href="https://my.nuevaschool.org/base.php?q__=a1fTAPItLZOqfLiDPOWNtGnMdOeemfSlPvVkLz%2BLWcs%2FsVNbSR7CtvPBGn7PDJH1">DIRECTORY</a><ul class="dropdown-menu"><li><a href="https://my.nuevaschool.org/base.php?q__=a1fTAPItLZOqfLiDPOWNtGnMdOeemfSlPvVkLz%2BLWcs%2FsVNbSR7CtvPBGn7PDJH1">COMMUNITY</a></li><li><a href="https://my.nuevaschool.org/base.php?q__=a1fTAPItLZOqfLiDPOWNtGnMdOeemfSlPvVkLz%2BLWcsE77ggloNZBCm8hmhZLfN7">FACULTY/STAFF</a></li><li><a href="https://my.nuevaschool.org/base.php?q__=a1fTAPItLZOqfLiDPOWNtGnMdOeemfSlPvVkLz%2BLWcuaWHo6yqEpgyUWUL2TgqEJ">BOARD</a></li><li><a href="https://my.nuevaschool.org/base.php?q__=a1fTAPItLZOqfLiDPOWNtGnMdOeemfSlPvVkLz%2BLWcv9mD3piPqsmk5vpsT75S00uUFcMcZ2VCm%2BN4pCzTUndA%3D%3D">ORGANIZATION</a></li><li><a href="https://my.nuevaschool.org/base.php?q__=a1fTAPItLZOqfLiDPOWNtGnMdOee ...
# <ul class="nav navbar-nav navbar-right"><form action="base.php?q__=lP4v3UlncdedfjT3hxdN5Xiibmrxf7p%2FbG%2BaqhU5qio%3D" class="navbar-form navbar-left" method="POST" role="search">
#     <div class="form-group">
#         <input class="form-control input-sm" name="query" placeholder="Search" type="text" value=""/>
#         <input name="subdomain" type="hidden" value=""/>
#     </div>
#     <button class="btn btn-info btn-sm" type="submit"><span class="glyphicon glyphicon-search"></span></button>
# </form></ul>
# </div><!--/.nav-collapse -->
# </div>
# </div><header style="background-color: #ccc;"><div class="container"><span class="glyphicon glyphicon-user" style="color:navy;"></span> <b>Carl Shan</b><form action="signin.php" id="signoutform" method="post" style="display:inline; margin-left:5px; "><input name="signin_bye" type="hidden" value="1"/><a class="btn btn-link btn-xs" href='javascript:document.getElementById("signoutform").submit();' type="button">Sign out</a><a class="btn btn-link btn-xs" href="base.php?q__=jhZgrJG%2Bt1FARM49hhhB0O4cAS2YFgs1jH29fYEdegiAAl6qyAOA0x9S0JBUkSwX" style="color:#text-decoration:none;margin-right:2px;" type="button">Change password</a></form></div>
">Brasesco, Scott</option><option value="17091">Brasesco, Jack</option><option value="16168">Braun, Tobias</option><option value="17971">Braylovskiy, Valerie</option><option value="16171">Breckenridge, Ishaan</option><option value="16174">Brougher, Gregoire</option><option value="12965">Brown, Gabriella</option><option value="12921">Burkhart, Calder</option><option value="14251">Burlinson, Nicolas</option><option value="10530">Bush-Peel, Elizabeth</option><option value="15593">Byun, Michael</option><option value="13736">Cabreza, Ava</option><option value="15504">Cadet, Ronald</option><option value="14278">Callan, Madeleine</option><opti ...
# 		<span>Draft emails (6)</span><div><p></p><ul><li><a href="base.php?q__=p9LZ%2FcnEk%2FkhbOyhnXibPbvxKMPKpaMnOC7HC6DbvSAjbsLfK9IzNadG3pNFPM%2Fq8XWt3KcgQEddSj7CgTFToOEGl0B8wS1%2FC4%2FAAYNcuz0%3D">type subject here</a></li><li><a href="base.php?q__=p9LZ%2FcnEk%2FkhbOyhnXibPbvxKMPKpaMnOC7HC6DbvSAjbsLfK9IzNadG3pNFPM%2Fqgg3kjC%2BS%2FtrAgkoV9Z6X93dcvCn%2BfawroRAbRvjyLuc%3D">To "MS Homework Digest" List</a></li><li><a href="base.php?q__=p9LZ%2FcnEk%2FkhbOyhnXibPbvxKMPKpaMnOC7HC6DbvSAjbsLfK9IzNadG3pNFPM%2FqfKqFDX7a%2FhZFcfIT%2FwFza%2BWPOzGhx8YruMOtBVnK4BQ%3D">type subject here</a></li><li><a href="base.php?q__=p9LZ%2FcnEk%2FkhbOyhnXibPbvxKMPKpaMnOC7HC6DbvSAjbsLfK9IzNadG3pNFPM%2FqSNh0SEULgnY9HyPHqEyku%2BqScn800Qee0ttmYmxKIow%3D">type subject here</a></li><li><a href="base.php?q__=p9LZ%2FcnEk%2FkhbOyhnXibPbvxKMPKpaMnOC7HC6DbvSAjbsLfK9IzNadG3pNFPM%2FqAxd5hoHP3iJqkUH0mLH54YYXB3t6Xkn%2FKkVk7aV6t7E%3D">type subject here</a></li><li><a href="base.php?q__=p9LZ%2FcnEk%2FkhbOyhnXibPbvxKMPKpaMnOC7HC6DbvSAjbsLfK9IzNadG3pNFPM%2Fq7qWFxJHOtMyawj0GHBIkNSMuyt0nr8mAEQHBVE1Z%2FRg%3D">To "12th Advisory -- Yuliya R. and Carl S. students" List</a></li></ul><p></p></div></div><style>
# .ui-accordion .ui-accordion-header{
# 	padding: 0 0 ! important;
# }
# .ui-state-default, .ui-widget-content .ui-state-default, .ui-widget-header .ui-state-default{
# 	border: none ! important;
# 	background: none ! important;
# }
# </style>
# <script type="text/javascript">
# 	$(function(){
# 		$( '#draft_email_accordion' ).accordion({
# 			header: "span",
#         	collapsible: true,
# 			active: false
#         });
# 		$( "#draft_email_accordion" ).accordion( "option", "icons", null );
#     });
# <form action="base.php?q__=p9LZ%2FcnEk%2FkhbOyhnXibPbYVpO5XvDf8aLa86CksUqw%3D" id="f__51421692" method="post" style="display: inline"><input name="allowAttachments" type="hidden" value="1"/><input name="allowCC" type="hidden" value="1"/><input name="add_parents_of" type="hidden" value=""/><input name="qy2" type="hidden" value="%28%28select+id_person%2C+active%2C+cluster%2C+name_last_sort%2C+name_first%2C++sender+from+person_mailing_list+natural+inner+join+person+where+id_mailing_list%3D14330+ORDER+BY+cluster%2C+name_last_sort%2C+name_first%29+UNION%0D%0A++++++++++++++++++++++++++++++++++++++++%28SELECT+id_person%2C+TRUE+as+active%2C+%27zzzzz%27+as+cluster%2C+name_last_sort%2C+name_first%2C+FALSE+as+sender+FROM+person+WHERE%0D%0A++++++++++++++++++++++++++++++++++++++++id_person+IN+%28%28SELECT+id_person+from+person_household+WHERE+id_household+in%0D%0A+++++++++++++++%28SELECT+id_household+from+person_household+NATURAL+INNER+JOIN+person_class%0D%0A+++++++++++++++++++++++WHERE+person_class.id_class%3D%2717597%27+AND+class_role%3D%27student%27%29%0D%0A++++++++++++++++INTERSECT+%28SELECT+id_person+from+person+NATURAL+INNER+JOIN+person_role%0D%0A++++++++++++++++++++++WHERE+id_role%3D4+OR+id_role%3D10008%29%29+UNION%0D%0A++++++++++++%28SELECT+id_person+from+person_role+WHERE+%28id_role%3D10044++OR+id_role%3D10004%29%0D%0A++++++++++++++INTERSECT%0D%0A+++++++++++++SELECT+id_person+from+person_role+WHERE+id_role%3D10040+%29+EXCEPT%0D%0A++++++++++++++++++++++++++++++++++++++++++++SELECT+id_person+FROM+person_mailing_list+WHERE+id_mailing_list%3D14330%29%29%0D%0A++++++++++++++++++++++++++++++++++++++++ORDER+BY+cluster%2C+name_last_sort%2C+name_first%29"/><input name="returnURL" type="hidden" value="home.php"/><input name="prompt" type="hidden" value="To+%2212th+Advisory+--+Yuliya+R.+and+Carl+S.+parents%22+List"/></form><script>function f__51421692(){document.getElementById('f__51421692').submit();}</script>
# <a href="javascript:f__51421692()">12th Advisory -- Yuliya R. and Carl S. parents</a>    <a href="base.php?q__=i9fQEkPEWohLPxLegrA7487d1RtuIO8kOEBaeZAno1Td9ar0ZZNfp%2F%2B%2BmuZhyGeIzOt9RF%2F5FrnEXoBMvSTtHg%3D%3D">manage list</a></li><li>
# <form action="base.php?q__=p9LZ%2FcnEk%2FkhbOyhnXibPbYVpO5XvDf8aLa86CksUqw%3D" id="f__64239809" method="post" style="display: inline"><input name="allowAttachments" type="hidden" value="1"/><input name="allowCC" type="hidden" value="1"/><input name="add_parents_of" type="hidden" value=""/><input name="qy2" type="hidden" value="%28%28select+id_person%2C+active%2C+cluster%2C+name_last_sort%2C+name_first%2C++sender+from+person_mailing_list+natural+inner+join+person+where+id_mailing_list%3D14331+ORDER+BY+cluster%2C+name_last_sort%2C+name_first%29+UNION%0D%0A++++++++++++++++++++++++++++++++++++++++%28SELECT+id_person%2C+TRUE+as+active%2C+%27zzzzz%27+as+cluster%2C+name_last_sort%2C+name_first%2C+FALSE+as+sender+FROM+person+WHERE%0D%0A++++++++++++++++++++++++++++++++++++++++id_person+IN+%28SELECT+id_person+FROM+person_class+WHERE+id_class%3D%2717597%27+AND+class_role%3D%27student%27++UNION%0D%0A++++++++++++%28SELECT+id_person+from+person_role+WHERE+%28id_role%3D10044++OR+id_role%3D10004%29%0D%0A++++++++++++++INTERSECT%0D%0A+++++++++++++SELECT+id_person+from+person_role+WHERE+id_role%3D10040+%29+EXCEPT%0D%0A++++++++++++++++++++++++++++++++++++++++++++SELECT+id_person+FROM+person_mailing_list+WHERE+id_mailing_list%3D14331%29%29%0D%0A++++++++++++++++++++++++++++++++++++++++ORDER+BY+cluster%2C+name_last_sort%2C+name_first%29"/><input name="returnURL" type="hidden" value="home.php"/><input name="prompt" type="hidden" value="To+%2212th+Advisory+--+Yuliya+R.+and+Carl+S.+students%22+List"/></form><script>function f__64239809(){document.getElementById('f__64239809').submit();}</script>
# <a href="javascript:f__64239809()">12th Advisory -- Yuliya R. and Carl S. students</a>    <a href="base.php?q__=i9fQEkPEWohLPxLegrA7487d1RtuIO8kOEBaeZAno1Td9ar0ZZNfp%2F%2B%2BmuZhyGeIZiVjDWJagMRpYJq1ESsTlg%3D%3D">manage list</a></li><li>
# <form action="base.php?q__=p9LZ%2FcnEk%2FkhbOyhnXibPbYVpO5XvDf8aLa86CksUqw%3D" id="f__21019633" method="post" style="display: inline"><input name="allowAttachments" type="hidden" value="1"/><input name="allowCC" type="hidden" value="1"/><input name="add_parents_of" type="hidden" value=""/><input name="qy2" type="hidden" value="select+id_person%2C+active%2C+cluster%2C+name_last_sort%2C+name_first%2C+sender+from+person_mailing_list+natural+inner+join+person+where+id_mailing_list%3D13845+ORDER+BY+cluster%2C+name_last_sort%2C+name_first%2C+sender"/><input name="returnURL" type="hidden" value="home.php"/><input name="prompt" type="hidden" value="To+%229th+Wellness+Mailing+List+2016-2017%22+List"/></form><script>function f__21019633(){document.getElementById('f__21019633').submit();}</script>
# <a href="javascript:f__21019633()">9th Wellness Mailing List 2016-2017</a>    </li><li>
# <form action="base.php?q__=p9LZ%2FcnEk%2FkhbOyhnXibPbYVpO5XvDf8aLa86CksUqw%3D" id="f__65025609" method="post" style="display: inline"><input name="allowAttachments" type="hidden" value="1"/><input name="allowCC" type="hidden" value="1"/><input name="add_parents_of" type="hidden" value=""/><input name="qy2" type="hidden" value="select+id_person%2C+active%2C+cluster%2C+name_last_sort%2C+name_first%2C+sender+from+person_mailing_list+natural+inner+join+person+where+id_mailing_list%3D12358+ORDER+BY+cluster%2C+name_last_sort%2C+name_first%2C+sender"/><input name="returnURL" type="hidden" value="home.php"/><input name="prompt" type="hidden" value="To+%22FRC+Kids+and+Parents%22+List"/></form><script>function f__65025609(){document.getElementById('f__65025609').submit();}</script>
# <a href="javascript:f__65025609()">FRC Kids and Parents</a>    </li><li>
# <form action="base.php?q__=p9LZ%2FcnEk%2FkhbOyhnXibPbYVpO5XvDf8aLa86CksUqw%3D" id="f__50796137" method="post" style="display: inline"><input name="allowAttachments" type="hidden" value="1"/><input name="allowCC" type="hidden" value="1"/><input name="add_parents_of" type="hidden" value=""/><input name="qy2" type="hidden" value="select+id_person%2C+active%2C+cluster%2C+name_last_sort%2C+name_first%2C+sender+from+person_mailing_list+natural+inner+join+person+where+id_mailing_list%3D13656+ORDER+BY+cluster%2C+name_last_sort%2C+name_first%2C+sender"/><input name="returnURL" type="hidden" value="home.php"/><input name="prompt" type="hidden" value="To+%22I-Lab+Staff%22+List"/></form><script>function f__50796137(){document.getElementById('f__50796137').submit();}</script>
# <a href="javascript:f__50796137()">I-Lab Staff</a>    </li><li>
# <form action="base.php?q__=p9LZ%2FcnEk%2FkhbOyhnXibPbYVpO5XvDf8aLa86CksUqw%3D" id="f__99581757" method="post" style="display: inline"><input name="allowAttachments" type="hidden" value="1"/><input name="allowCC" type="hidden" value="1"/><input name="add_parents_of" type="hidden" value=""/><input name="qy2" type="hidden" value="select+id_person%2C+active%2C+cluster%2C+name_last_sort%2C+name_first%2C+sender+from+person_mailing_list+natural+inner+join+person+where+id_mailing_list%3D13841+ORDER+BY+cluster%2C+name_last_sort%2C+name_first%2C+sender"/><input name="returnURL" type="hidden" value="home.php"/><input name="prompt" type="hidden" value="To+%22New+US+Faculty+2016-2017%22+List"/></form><script>function f__99581757(){document.getElementById('f__99581757').submit();}</script>
# <a href="javascript:f__99581757()">New US Faculty 2016-2017</a>    </li><li>
# <form action="base.php?q__=p9LZ%2FcnEk%2FkhbOyhnXibPbYVpO5XvDf8aLa86CksUqw%3D" id="f__35030215" method="post" style="display: inline"><input name="allowAttachments" type="hidden" value="1"/><input name="allowCC" type="hidden" value="1"/><input name="add_parents_of" type="hidden" value=""/><input name="qy2" type="hidden" value="select+id_person%2C+active%2C+cluster%2C+name_last_sort%2C+name_first%2C+sender+from+person_mailing_list+natural+inner+join+person+where+id_mailing_list%3D12638+ORDER+BY+cluster%2C+name_last_sort%2C+name_first%2C+sender"/><input name="returnURL" type="hidden" value="home.php"/><input name="prompt" type="hidden" value="To+%22US+Programming+Club%22+List"/></form><script>function f__35030215(){document.getElementById('f__35030215').submit();}</script>
# <a href="javascript:f__35030215()">US Programming Club</a>    </li><li>
# <form action="base.php?q__=p9LZ%2FcnEk%2FkhbOyhnXibPbYVpO5XvDf8aLa86CksUqw%3D" id="f__18848656" method="post" style="display: inline"><input name="allowAttachments" type="hidden" value="1"/><input name="allowCC" type="hidden" value="1"/><input name="add_parents_of" type="hidden" value=""/><input name="qy2" type="hidden" value="select+id_person%2C+active%2C+cluster%2C+name_last_sort%2C+name_first%2C+sender+from+person_mailing_list+natural+inner+join+person+where+id_mailing_list%3D13216+ORDER+BY+cluster%2C+name_last_sort%2C+name_first%2C+sender"/><input name="returnURL" type="hidden" value="home.php"/><input name="prompt" type="hidden" value="To+%22Upper+School+Advisors%22+List"/></form><script>function f__18848656(){document.getElementById('f__18848656').submit();}</script>
# <a href="javascript:f__18848656()">Upper School Advisors</a>    </li><li>
# <form action="base.php?q__=p9LZ%2FcnEk%2FkhbOyhnXibPbYVpO5XvDf8aLa86CksUqw%3D" id="f__58991214" method="post" style="display: inline"><input name="allowAttachments" type="hidden" value="1"/><input name="allowCC" type="hidden" value="1"/><input name="add_parents_of" type="hidden" value=""/><input name="qy2" type="hidden" value="%28%28select+id_person%2C+active%2C+cluster%2C+name_last_sort%2C+name_first%2C++sender+from+person_mailing_list+natural+inner+join+person+where+id_mailing_list%3D12236+ORDER+BY+cluster%2C+name_last_sort%2C+name_first%29+UNION%0D%0A++++++++++++++++++++++++++++++++++++++++%28SELECT+id_person%2C+TRUE+as+active%2C+%27zzzzz%27+as+cluster%2C+name_last_sort%2C+name_first%2C+FALSE+as+sender+FROM+person+WHERE%0D%0A++++++++++++++++++++++++++++++++++++++++id_person+IN+%28select+id_person+FROM%0D%0Aperson_role+%0D%0Anatural+inner+join+role+%0D%0Awhere+role.name+in+%28%27faculty%27%2C+%27TA%27%2C+%27adjunct_faculty%27%29%0D%0AINTERSECT%0D%0Aselect+id_person+FROM%0D%0Aperson_role+%0D%0Anatural+inner+join+role+%0D%0Awhere+role.name+%3D+%27affiliate_us%27+EXCEPT%0D%0A++++++++++++++++++++++++++++++++++++++++++++SELECT+id_person+FROM+person_mailing_list+WHERE+id_mailing_list%3D12236%29%29%0D%0A++++++++++++++++++++++++++++++++++++++++ORDER+BY+cluster%2C+name_last_sort%2C+name_first%29"/><input name="returnURL" type="hidden" value="home.php"/><input name="prompt" type="hidden" value="To+%22Upper+School+All+Faculty%22+List"/></form><script>function f__58991214(){document.getElementById('f__58991214').submit();}</script>
# <a href="javascript:f__58991214()">Upper School All Faculty</a>    </li><li>
# <form action="base.php?q__=p9LZ%2FcnEk%2FkhbOyhnXibPbYVpO5XvDf8aLa86CksUqw%3D" id="f__54928237" method="post" style="display: inline"><input name="allowAttachments" type="hidden" value="1"/><input name="allowCC" type="hidden" value="1"/><input name="add_parents_of" type="hidden" value=""/><input name="qy2" type="hidden" value="%28%28select+id_person%2C+active%2C+cluster%2C+name_last_sort%2C+name_first%2C++sender+from+person_mailing_list+natural+inner+join+person+where+id_mailing_list%3D12030+ORDER+BY+cluster%2C+name_last_sort%2C+name_first%29+UNION%0D%0A++++++++++++++++++++++++++++++++++++++++%28SELECT+id_person%2C+TRUE+as+active%2C+%27zzzzz%27+as+cluster%2C+name_last_sort%2C+name_first%2C+FALSE+as+sender+FROM+person+WHERE%0D%0A++++++++++++++++++++++++++++++++++++++++id_person+IN+%28select+id_person+FROM%0D%0Aperson_role+%0D%0Anatural+inner+join+role+%0D%0Awhere+role.name+in+%28%27faculty%27%2C+%27TA%27%2C+%27specialist%27%2C+%27admin_email_cc%27%2C+%27adjunct_faculty%27%2C+%27staff%27%29%0D%0AINTERSECT%0D%0Aselect+id_person+FROM%0D%0Aperson_role+%0D%0Anatural+inner+join+role+%0D%0Awhere+role.name+%3D+%27affiliate_us%27+EXCEPT%0D%0A++++++++++++++++++++++++++++++++++++++++++++SELECT+id_person+FROM+person_mailing_list+WHERE+id_mailing_list%3D12030%29%29%0D%0A++++++++++++++++++++++++++++++++++++++++ORDER+BY+cluster%2C+name_last_sort%2C+name_first%29"/><input name="returnURL" type="hidden" value="home.php"/><input name="prompt" type="hidden" value="To+%22Upper+School+Faculty+%26+Staff%22+List"/></form><script>function f__54928237(){document.getElementById('f__54928237').submit();}</script>
# <a href="javascript:f__54928237()">Upper School Faculty &amp; Staff</a>    </li></ul></div></div></div></div></div>
#
#
#
#
#
#
# </div></div>
# </div></body></html>
